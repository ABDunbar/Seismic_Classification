# %% [markdown]
# # Petrel Seismic Attributes
#
# This notebook reads in a cropped segy volume that was exported from Petrel. It reads in a surface and some pre-saved surface attributes. It loads the segy and surfaces into `xarray`.  The surfaces provide the input for the feature vector that will be used in the unsupervised classification.
#
# * Load segy file to `xarray`.
# * Import Petrel surfaces (seismic extracted attributes converted to surface)
# * Load Petrel surfaces to xarray
# * Plot surface attributes using `griddata` from `scipy.interpolate`
# * Create classification vector in numpy from Dataframe object
# * Run unsupervised classification

# %%
import pathlib
import platform
from IPython.display import display

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead
import xarray as xr

# %%
seis_path = pathlib.Path("Attributes/amplitude.segy")
print("3D", seis_path, seis_path.exists())

amp = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)

amp = amp.set_coords(("cdp_x", "cdp_y"))

amp.to_netcdf('Attributes/Amplitudes.nc')
# Out:
# 3D Attributes\amplitude.segy True
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/58.3k [00:00<?, ? traces/s]

# %%
seis_path = pathlib.Path("Attributes/3D_edge_enh.segy")
print("3D", seis_path, seis_path.exists())

edge = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



edge = edge.set_coords(("cdp_x", "cdp_y"))


edge.to_netcdf('Attributes/Edge_3D_enhance.nc')

# %%
seis_path = pathlib.Path("Attributes/AppPol_w33.segy")
print("3D", seis_path, seis_path.exists())

pol = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



pol = pol.set_coords(("cdp_x", "cdp_y"))


pol.to_netcdf('Attributes/Apparent_polarity_w33.nc')

# %%
seis_path = pathlib.Path("Attributes/DomFreq_w33.segy")
print("3D", seis_path, seis_path.exists())

domfreq = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



domfreq = domfreq.set_coords(("cdp_x", "cdp_y"))


domfreq.to_netcdf('Attributes/Dominant_frequency_w33.nc')

# %%
seis_path = pathlib.Path("Attributes/Env_w33.segy")
print("3D", seis_path, seis_path.exists())

env = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



env = env.set_coords(("cdp_x", "cdp_y"))


env.to_netcdf('Attributes/Envelope_w33.nc')

# %%
seis_path = pathlib.Path("Attributes/GLCM_I.segy")
print("3D", seis_path, seis_path.exists())

glcmi = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



glcmi = glcmi.set_coords(("cdp_x", "cdp_y"))


glcmi.to_netcdf('Attributes/GLCM_I.nc')

# %%
seis_path = pathlib.Path("Attributes/InstPhase_w33.segy")
print("3D", seis_path, seis_path.exists())

phase = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



phase = phase.set_coords(("cdp_x", "cdp_y"))


phase.to_netcdf('Attributes/Instantaneous_phase_w33.nc')

# %%
seis_path = pathlib.Path("Attributes/RAI_lc10.segy")
print("3D", seis_path, seis_path.exists())

rai = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



rai = rai.set_coords(("cdp_x", "cdp_y"))


rai.to_netcdf('Attributes/RAI_lc10.nc')

# %%
seis_path = pathlib.Path("Attributes/Struct_smooth_1pt2.segy")
print("3D", seis_path, seis_path.exists())

smooth = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



smooth = smooth.set_coords(("cdp_x", "cdp_y"))


smooth.to_netcdf('Attributes/Structural_smooth_1pt2.nc')

# %%
seis_path = pathlib.Path("Attributes/Sweet_w33.segy")
print("3D", seis_path, seis_path.exists())

sweet = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



sweet = sweet.set_coords(("cdp_x", "cdp_y"))


sweet.to_netcdf('Attributes/Sweetness_w33.nc')

# %%
seis_path = pathlib.Path("Attributes/Variance.segy")
print("3D", seis_path, seis_path.exists())

var = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



var = var.set_coords(("cdp_x", "cdp_y"))


var.to_netcdf('Attributes/Variance.nc')
# Out:
# 3D Attributes\Variance.segy True
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/58.3k [00:00<?, ? traces/s]

# %%
seis_path = pathlib.Path("Attributes/3D_curve.segy")
print("3D", seis_path, seis_path.exists())

curve = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



curve = curve.set_coords(("cdp_x", "cdp_y"))


curve.to_netcdf('Attributes/Curvature3D.nc')
# Out:
# 3D Attributes\3D_curve.segy True
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/58.3k [00:00<?, ? traces/s]

# %%
seis_path = pathlib.Path("Attributes/Chaos.segy")
print("3D", seis_path, seis_path.exists())

chaos = xr.open_dataset(
    seis_path,
    dim_byte_fields={"iline" : 5, "xline" : 21},
    extra_byte_fields={"cdp_x" : 73, "cdp_y" : 77},
)



chaos = chaos.set_coords(("cdp_x", "cdp_y"))


chaos.to_netcdf('Attributes/Chaos.nc')
# Out:
# 3D Attributes\Chaos.segy True
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/58.3k [00:00<?, ? traces/s]

# %%
opt = dict(
    x="iline",
    y="samples",
    add_colorbar=True,
    interpolation="spline16",
    robust=True,
    yincrease=False,
    cmap="seismic_r",
)

xline = 10486

f, ax = plt.subplots(nrows=1, figsize=(12, 6), sharey=True, constrained_layout=True)

pol.data.sel(xline=xline, samples=slice(1900, 2500)).plot.imshow(ax=ax, **opt)
x1, t1 = cube.Tau_TWT.sel(xline=xline).iline, cube.Tau_TWT.sel(xline=xline)
x2, t2 = cube.Sandnes_TWT.sel(xline=xline).iline, cube.Sandnes_TWT.sel(xline=xline)
x3, t3 = cube.Bryne_TWT.sel(xline=xline).iline, cube.Bryne_TWT.sel(xline=xline)

ax.plot(x1, t1, color="b")
ax.plot(x2, t2, color="orange")
ax.plot(x3, t3, color="r")

ax.invert_xaxis()
